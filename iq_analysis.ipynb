# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")
df=pd.read_excel("/content/IQ-TEST (Responses).xlsx")
df
# Out:
#                   Timestamp                  NAME  AGE  GENDER  \
# 0   2024-07-26 12:23:29.399                Rukesh   21    MALE
# 1   2024-07-26 12:23:51.658                  Pris   22  FEMALE
# 2   2024-07-26 12:24:33.802  SHERIN LINCY MARY R    22  FEMALE
# 3   2024-07-26 12:47:09.212                 Brain   23  FEMALE
# 4   2024-07-26 13:10:02.851               Swetha    25  FEMALE
# ..                      ...                   ...  ...     ...
# 200 2024-07-26 23:48:42.608        Soosai Riyas M   21    MALE
# 201 2024-07-27 01:06:45.599              Snekha G   21  FEMALE
# 202 2024-07-27 08:04:06.910         Felix Rosario   21    MALE
# 203 2024-07-27 12:07:30.026           Bakiyasree    21  FEMALE
# 204 2024-07-27 17:02:56.130        Udith Shiny A    21  FEMALE
#
#       Dog is to Bark as Cat is to:      What is the synonym of "Abundant"?  \
# 0                            a) Meow                          b) Plentiful
# 1                            a) Meow                          b) Plentiful
# 2                            a) Meow                          b) Plentiful
# 3                            a) Meow                          b) Plentiful
# 4                            a) Meow                          b) Plentiful
# ..                               ...                                   ...
# 200                          a) Meow                               c) Rare
# 201                          a) Meow                               c) Rare
# 202                          a) Meow                               c) Rare
# 203                          a) Meow                             a) Scarce
# 204                          a) Meow                             a) Scarce
#
#        Fish is to Swim as Bird is to     What is the antonym of "Generous"?    \
# 0                               d) Run                                b) Kind
# 1                             c) Crawl                                b) Kind
# 2                               a) Fly                              a) Stingy
# 3                               a) Fly                              a) Stingy
# 4                               a) Fly                              a) Stingy
# ..                                 ...                                    ...
# 200                             a) Fly                         d) Open-handed
# 201                             a) Fly                              a) Stingy
# 202                             a) Fly                              c) Lavish
# 203                             a) Fly                              a) Stingy
# 204                             a) Fly                                b) Kind
#
#       What comes next in the series: 2, 4, 8, 16, ...?    \
# 0                                                c) 32
# 1                                                b) 28
# 2                                                c) 32
# 3                                                c) 32
# 4                                                c) 32
# ..                                                 ...
# 200                                              c) 32
# 201                                              c) 32
# 202                                              c) 32
# 203                                              c) 32
# 204                                              c) 32
#
#        What is 25% of 500?    ...  \
# 0                        125  ...
# 1                        125  ...
# 2                        120  ...
# 3                        125  ...
# 4                        125  ...
# ..                       ...  ...
# 200                      125  ...
# 201                      125  ...
# 202                      125  ...
# 203                      125  ...
# 204                      125  ...
#
#       What comes next in the series: A, B, D, G, ...?    \
# 0                                                 b) J
# 1                                                 c) K
# 2                                                 c) K
# 3                                                 c) K
# 4                                                 c) K
# ..                                                 ...
# 200                                               b) J
# 201                                               c) K
# 202                                               c) K
# 203                                               c) K
# 204                                               c) K
#
#        How many 4's are in the following sequence: 434284943?    \
# 0                                                 c) 4
# 1                                                 a) 2
# 2                                                 c) 4
# 3                                                 c) 4
# 4                                                 d) 5
# ..                                                 ...
# 200                                               c) 4
# 201                                               c) 4
# 202                                               c) 4
# 203                                               c) 4
# 204                                               c) 4
#
#        How many vowels are in the following word: "Examination"?    \
# 0                                                 c) 6
# 1                                                 d) 7
# 2                                                 c) 6
# 3                                                 c) 6
# 4                                                 c) 6
# ..                                                 ...
# 200                                               b) 5
# 201                                               c) 6
# 202                                               c) 6
# 203                                               c) 6
# 204                                               c) 6
#
#        Find the odd one out: cat, dog, bird, fish    \
# 0                                            b) Dog
# 1                                            a) Cat
# 2                                           c) Bird
# 3                                           d) Fish
# 4                                           c) Bird
# ..                                              ...
# 200                                         c) Bird
# 201                                         d) Fish
# 202                                         d) Fish
# 203                                         d) Fish
# 204                                         d) Fish
#
#        How many 2's are in the following sequence: 122322124?   Score  \
# 0                                                 c) 5              8
# 1                                                 d) 6              5
# 2                                                 c) 5             12
# 3                                                 c) 5             15
# 4                                                  NaN             11
# ..                                                 ...            ...
# 200                                               c) 5              8
# 201                                               c) 5             14
# 202                                               c) 5             13
# 203                                               c) 5             14
# 204                                               c) 5             13
#
#     total score       MEAN      STD          IQ
# 0             8  11.829268  3.02686   81.023564
# 1             5  11.829268  3.02686   66.156674
# 2            12  11.829268  3.02686  100.846083
# 3            15  11.829268  3.02686  115.712973
# 4            11  11.829268  3.02686   95.890453
# ..          ...        ...      ...         ...
# 200           8  11.829268  3.02686   81.023564
# 201          14  11.829268  3.02686  110.757343
# 202          13  11.829268  3.02686  105.801713
# 203          14  11.829268  3.02686  110.757343
# 204          13  11.829268  3.02686  105.801713
#
# [205 rows x 28 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 28 columns):
#  #   Column                                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                                          --------------  -----
#  0   Timestamp                                                                                                                       205 non-null    datetime64[ns]
#  1   NAME                                                                                                                            205 non-null    object
#  2   AGE                                                                                                                             205 non-null    int64
#  3   GENDER                                                                                                                          205 non-null    object
#  4     Dog is to Bark as Cat is to:                                                                                                  205 non-null    object
#  5      What is the synonym of "Abundant"?                                                                                           205 non-null    object
#  6      Fish is to Swim as Bird is to                                                                                                205 non-null    object
#  7     What is the antonym of "Generous"?                                                                                            205 non-null    object
#  8     What comes next in the series: 2, 4, 8, 16, ...?                                                                              205 non-null    object
#  9     What is 25% of 500?                                                                                                           205 non-null    int64
#  10    What is 15% of 200?                                                                                                           205 non-null    object
#  11  Remember the following sequence: 3, 7, 2, 9, 5. What was the third number?                                                      0 non-null      float64
#  12     Solve 12 + 7 while remembering the number sequence: 4, 6, 8, 2. What is the result and the second number in the sequence?    0 non-null      float64
#  13     Remember the following words: apple, dog, car, tree, house. Which word was not in the list?                                  0 non-null      float64
#  14     Multiply 6 by 3 while remembering the word list: hat, shoe, book. What is the result and the second word in the list?        0 non-null      float64
#  15    What comes next in the pattern: ▲, ■, ▲, ■, ...?                                                                              205 non-null    object
#  16    What comes next in the series: 1, 4, 9, 16, ...?                                                                              205 non-null    object
#  17    What comes next in the pattern: ●, ○, ●, ○, ...?                                                                              205 non-null    object
#  18    What comes next in the series: A, B, D, G, ...?                                                                               205 non-null    object
#  19    How many 4's are in the following sequence: 434284943?                                                                        205 non-null    object
#  20    How many vowels are in the following word: "Examination"?                                                                     205 non-null    object
#  21    Find the odd one out: cat, dog, bird, fish                                                                                    205 non-null    object
#  22    How many 2's are in the following sequence: 122322124?                                                                        200 non-null    object
#  23  Score                                                                                                                           205 non-null    int64
#  24  total score                                                                                                                     205 non-null    int64
#  25  MEAN                                                                                                                            205 non-null    float64
#  26  STD                                                                                                                             205 non-null    float64
#  27  IQ                                                                                                                              205 non-null    float64
# dtypes: datetime64[ns](1), float64(7), int64(4), object(16)
# memory usage: 45.0+ KB

# %%
df.isnull().sum()
# Out:
# Timestamp                                                                                                                           0
# NAME                                                                                                                                0
# AGE                                                                                                                                 0
# GENDER                                                                                                                              0
#   Dog is to Bark as Cat is to:                                                                                                      0
#    What is the synonym of "Abundant"?                                                                                               0
#    Fish is to Swim as Bird is to                                                                                                    0
#   What is the antonym of "Generous"?                                                                                                0
#   What comes next in the series: 2, 4, 8, 16, ...?                                                                                  0
#   What is 25% of 500?                                                                                                               0
#   What is 15% of 200?                                                                                                               0
# Remember the following sequence: 3, 7, 2, 9, 5. What was the third number?                                                        205
#    Solve 12 + 7 while remembering the number sequence: 4, 6, 8, 2. What is the result and the second number in the sequence?      205
#    Remember the following words: apple, dog, car, tree, house. Which word was not in the list?                                    205
#    Multiply 6 by 3 while remembering the word list: hat, shoe, book. What is the result and the second word in the list?          205
#   What comes next in the pattern: ▲, ■, ▲, ■, ...?                                                                                  0
#   What comes next in the series: 1, 4, 9, 16, ...?                                                                                  0
#   What comes next in the pattern: ●, ○, ●, ○, ...?                                                                                  0
#   What comes next in the series: A, B, D, G, ...?                                                                                   0
#   How many 4's are in the following sequence: 434284943?                                                                            0
#   How many vowels are in the following word: "Examination"?                                                                         0
#   Find the odd one out: cat, dog, bird, fish                                                                                        0
#   How many 2's are in the following sequence: 122322124?                                                                            5
# Score                                                                                                                               0
# total score                                                                                                                         0
# MEAN                                                                                                                                0
# STD                                                                                                                                 0
# IQ                                                                                                                                  0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['GENDER']=le.fit_transform(df['GENDER'])

# %%
import matplotlib.pyplot as plt
plt.scatter(df['total score'], df['IQ'])
plt.xlabel('Total Score')
plt.ylabel('IQ')
plt.title('Scatter Plot of Total Score vs IQ')
plt.show()

# %%
df1=df[['AGE','GENDER','total score','IQ']]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(df1.corr(),annot=True)
plt.show()

# %%
X=df['total score']
Y=df['IQ']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
X_train=X_train.values.reshape(-1,1)
X_test=X_test.values.reshape(-1,1)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
X_train
# Out:
# array([[14],
#        [12],
#        [10],
#        [13],
#        [13],
#        [10],
#        [14],
#        [10],
#        [12],
#        [15],
#        [13],
#        [13],
#        [14],
#        [11],
#        [12],
#        [15],
#        [14],
#        [12],
#        [ 4],
#        [ 9],
#        [14],
#        [11],
#        [ 5],
#        [15],
#        [12],
#        [13],
#        [ 4],
#        [12],
#        [ 5],
#        [12],
#        [11],
#        [14],
#        [15],
#        [12],
#        [12],
#        [ 8],
#        [ 5],
#        [14],
#        [14],
#        [14],
#        [13],
#        [ 8],
#        [ 4],
#        [12],
#        [ 8],
#        [12],
#        [13],
#        [11],
#        [15],
#        [14],
#        [ 8],
#        [ 4],
#        [11],
#        [14],
#        [13],
#        [14],
#        [12],
#        [11],
#        [ 4],
#        [13],
#        [13],
#        [11],
#        [15],
#        [ 4],
#        [15],
#        [11],
#        [ 4],
#        [11],
#        [15],
#        [12],
#        [14],
#        [15],
#        [ 9],
#        [ 8],
#        [11],
#        [13],
#        [ 8],
#        [11],
#        [15],
#        [12],
#        [14],
#        [15],
#        [15],
#        [ 5],
#        [14],
#        [13],
#        [14],
#        [ 8],
#        [15],
#        [ 4],
#        [14],
#        [13],
#        [14],
#        [13],
#        [13],
#        [13],
#        [ 4],
#        [12],
#        [15],
#        [15],
#        [15],
#        [13],
#        [15],
#        [ 9],
#        [13],
#        [14],
#        [13],
#        [14],
#        [ 5],
#        [14],
#        [14],
#        [14],
#        [ 5],
#        [14],
#        [14],
#        [14],
#        [13],
#        [11],
#        [15],
#        [13],
#        [13],
#        [14],
#        [12],
#        [14],
#        [11],
#        [14],
#        [ 5],
#        [14],
#        [11],
#        [14],
#        [14],
#        [14],
#        [12],
#        [14],
#        [14],
#        [13],
#        [ 9],
#        [14],
#        [14],
#        [12],
#        [13],
#        [14],
#        [ 5],
#        [12],
#        [ 5],
#        [11],
#        [14],
#        [14],
#        [14],
#        [ 9],
#        [14],
#        [ 5],
#        [12],
#        [12],
#        [14],
#        [13],
#        [11],
#        [10],
#        [10],
#        [10],
#        [13],
#        [15],
#        [14],
#        [11]])

# %%
Y_train
# Out:
# 66     110.757343
# 111    100.846083
# 153     90.934823
# 96     105.801713
# 38     105.801713
#           ...
# 106     90.934823
# 14     105.801713
# 92     115.712973
# 179    110.757343
# 102     95.890453
# Name: IQ, Length: 164, dtype: float64

# %%
print(lr.score(X_train,Y_train))
# Out:
# 1.0

# %%
from sklearn.metrics import r2_score
y_pred=lr.predict(X_test)
r2_score(Y_test,y_pred)
# Out:
# 1.0

# %%
from sklearn.metrics import mean_squared_error
mse=mean_squared_error(Y_test,y_pred)
mse
# Out:
# 1.2437065588655171e-28

# %%
from sklearn.metrics import mean_absolute_error
mae=mean_absolute_error(Y_test,y_pred)
mae
# Out:
# 8.491852207864612e-15

# %%
print(lr.predict([[15]]))
# Out:
# [115.71297263]

# %% [markdown]
# <50 - very low
#
# 50-70 - low
#
# 70-90 - moderate
#
# 90-105 - high
#
# >105 - very high

# %%
# age,gender have no effect oon IQ level
