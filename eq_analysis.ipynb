# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")
df=pd.read_excel("/content/Blank Quiz (Responses).xlsx")
df
# Out:
#                       Timestamp                  NAME   AGE  GENDER  \
# 0    2024-07-26 12:59:43.109000  SHERIN LINCY MARY R   22.0  FEMALE
# 1    2024-07-26 13:00:14.822000                  Hiii  23.0  FEMALE
# 2    2024-07-26 13:20:52.073000               DEEPA.P  21.0  FEMALE
# 3    2024-07-26 13:22:53.951000    Subhikshaa Suresh   21.0  FEMALE
# 4    2024-07-26 13:29:08.071000               Jothi K  22.0  FEMALE
# ..                          ...                   ...   ...     ...
# 150          7-26-2024 23:45:31              Joeakash  18.0    MALE
# 151           7-27-2024 1:14:05              Snekha G  21.0  FEMALE
# 152           7-27-2024 7:57:39         Felix Rosario  21.0    MALE
# 153          7-27-2024 12:08:33                   NaN   NaN     NaN
# 154          7-27-2024 20:34:31        Udith Shiny A   21.0  FEMALE
#
#      Do you often avoid unpleasant tasks as much as you can, in hope that you might not need to do them?  \
# 0                                                    4
# 1                                                    3
# 2                                                    1
# 3                                                    3
# 4                                                    1
# ..                                                 ...
# 150                                                  3
# 151                                                  3
# 152                                                  2
# 153                                                  5
# 154                                                  1
#
#      Do you often manage to acknowledge when you are angry so that you are able to control your behavior?   \
# 0                                                    4
# 1                                                    3
# 2                                                    1
# 3                                                    4
# 4                                                    1
# ..                                                 ...
# 150                                                  3
# 151                                                  3
# 152                                                  5
# 153                                                  3
# 154                                                  1
#
#      When you know you need to finish something do you often stay focused and avoid being distracted by any details that might compromise your plan?  \
# 0                                                    2
# 1                                                    4
# 2                                                    1
# 3                                                    2
# 4                                                    1
# ..                                                 ...
# 150                                                  3
# 151                                                  3
# 152                                                  5
# 153                                                  3
# 154                                                  2
#
#      I sometimes find it hard to figure out how people around me are feeling.  \
# 0                                                    2
# 1                                                    4
# 2                                                    2
# 3                                                    3
# 4                                                    1
# ..                                                 ...
# 150                                                  3
# 151                                                  3
# 152                                                  3
# 153                                                  4
# 154                                                  2
#
#      I have control over my emotions.  I am confident in social situations.  \
# 0                                   4                                     4
# 1                                   3                                     3
# 2                                   4                                     1
# 3                                   2                                     1
# 4                                   1                                     1
# ..                                ...                                   ...
# 150                                 3                                     3
# 151                                 2                                     4
# 152                                 4                                     4
# 153                                 1                                     4
# 154                                 2                                     3
#
#      I find it hard to put how I am feeling into words.  \
# 0                                                    3
# 1                                                    3
# 2                                                    3
# 3                                                    4
# 4                                                    1
# ..                                                 ...
# 150                                                  3
# 151                                                  3
# 152                                                  5
# 153                                                  2
# 154                                                  1
#
#      I constantly feel grateful for the life I have.  \
# 0                                                  5
# 1                                                  3
# 2                                                  3
# 3                                                  2
# 4                                                  1
# ..                                               ...
# 150                                                3
# 151                                                3
# 152                                                4
# 153                                                3
# 154                                                1
#
#      I really enjoy socializing.  \
# 0                              1
# 1                              4
# 2                              2
# 3                              5
# 4                              1
# ..                           ...
# 150                            3
# 151                            2
# 152                            5
# 153                            4
# 154                            2
#
#      I am very good at identifying the emotions I am feeling  TOTAL    EQ
# 0                                                    4           33  66.0
# 1                                                    2           32  64.0
# 2                                                    2           20  40.0
# 3                                                    2           28  56.0
# 4                                                    1           10  20.0
# ..                                                 ...          ...   ...
# 150                                                  3           30  60.0
# 151                                                  2           28  56.0
# 152                                                  4           41  82.0
# 153                                                  3           32  64.0
# 154                                                  1           16  32.0
#
# [155 rows x 16 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 16 columns):
#  #   Column                                                                                                                                           Non-Null Count  Dtype
# ---  ------                                                                                                                                           --------------  -----
#  0   Timestamp                                                                                                                                        155 non-null    object
#  1   NAME                                                                                                                                             150 non-null    object
#  2   AGE                                                                                                                                              150 non-null    float64
#  3   GENDER                                                                                                                                           150 non-null    object
#  4   Do you often avoid unpleasant tasks as much as you can, in hope that you might not need to do them?                                              155 non-null    int64
#  5   Do you often manage to acknowledge when you are angry so that you are able to control your behavior?                                             155 non-null    int64
#  6   When you know you need to finish something do you often stay focused and avoid being distracted by any details that might compromise your plan?  155 non-null    int64
#  7   I sometimes find it hard to figure out how people around me are feeling.                                                                         155 non-null    int64
#  8   I have control over my emotions.                                                                                                                 155 non-null    int64
#  9   I am confident in social situations.                                                                                                             155 non-null    int64
#  10  I find it hard to put how I am feeling into words.                                                                                               155 non-null    int64
#  11  I constantly feel grateful for the life I have.                                                                                                  155 non-null    int64
#  12  I really enjoy socializing.                                                                                                                      155 non-null    int64
#  13  I am very good at identifying the emotions I am feeling                                                                                          155 non-null    int64
#  14  TOTAL                                                                                                                                            155 non-null    int64
#  15  EQ                                                                                                                                               155 non-null    float64
# dtypes: float64(2), int64(11), object(3)
# memory usage: 19.5+ KB

# %%
df.isnull().sum()
# Out:
# Timestamp                                                                                                                                          0
# NAME                                                                                                                                               5
# AGE                                                                                                                                                5
# GENDER                                                                                                                                             5
# Do you often avoid unpleasant tasks as much as you can, in hope that you might not need to do them?                                                0
# Do you often manage to acknowledge when you are angry so that you are able to control your behavior?                                               0
# When you know you need to finish something do you often stay focused and avoid being distracted by any details that might compromise your plan?    0
# I sometimes find it hard to figure out how people around me are feeling.                                                                           0
# I have control over my emotions.                                                                                                                   0
# I am confident in social situations.                                                                                                               0
# I find it hard to put how I am feeling into words.                                                                                                 0
# I constantly feel grateful for the life I have.                                                                                                    0
# I really enjoy socializing.                                                                                                                        0
# I am very good at identifying the emotions I am feeling                                                                                            0
# TOTAL                                                                                                                                              0
# EQ                                                                                                                                                 0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['GENDER']=le.fit_transform(df['GENDER'])

# %%
X=df.drop(['NAME','Timestamp'],axis=1)
Y=df['EQ']

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(X.corr(),annot=True)
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
print(lr.score(X_train,Y_train))
# Out:
# 1.0

# %%
from sklearn.metrics import r2_score
y_pred=lr.predict(X_test)
r2_score(Y_test,y_pred)
# Out:
# 1.0

# %%
from sklearn.metrics import mean_squared_error
mse=mean_squared_error(Y_test,y_pred)
mse

# %%
from sklearn.metrics import mean_absolute_error
mae=mean_absolute_error(Y_test,y_pred)
mae

# %%
print(lr.predict([[20,0,50]]))

# %% [markdown]
# <20 - very low
#
# 20-40 - low
#
# 40-60 - moderate
#
# 60-80 - high
#
# 80-100 - very high

# %%
# age,gender have no effect on EQ level
